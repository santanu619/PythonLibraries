# %%
'''
@Author: Santanu Mohapatra
@Date: 18/06/2021
@Last Modified by: Santanu Mohapatra
@Last Modified Time: 17:15 PM
@Title: Python program to plot different lines.
'''

import numpy as np
import matplotlib.pyplot as plt

array_range = np.arange(0., 5., 0.2)

plt.plot(array_range, array_range, 'g--', array_range, array_range**2, 'bs', array_range, array_range**3, 'r^')
plt.show()
