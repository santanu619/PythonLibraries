# %%
'''
@Author: Santanu Mohapatra
@Date: 18/06/2021
@Last Modified by: Santanu Mohapatra
@Last Modified Time: 13:00 PM
@Title: Python program to plot by reading data from text file.
'''
import matplotlib.pyplot as plt
with open("test.txt") as text: 
    data = text.read()
data = data.split('\n')
X = [row.split(' ')[0] for row in data]
Y = [row.split(' ')[1] for row in data]
print("Values of X:")
print(X) 
print("Values of Y:")
print(Y)
plt.plot(X, Y)
plt.xlabel('x - axis')
plt.ylabel('y - axis')
plt.title('Straight Line')
plt.show()
# Out:
# Values of X:
# ['1', '2', '3']
# Values of Y:
# ['2', '4', '1']
