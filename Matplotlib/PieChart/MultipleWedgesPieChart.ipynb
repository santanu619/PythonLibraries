# %%
'''
@Author: Santanu Mohapatra
@Date: 20/06/2021
@Last Modified by: Santanu Mohapatra
@Last Modified Time: 11:40 AM
@Title: Python program to create a pie chart of the popularity of programming languages giving multiple wedges.
'''

import matplotlib.pyplot as plt

languages = 'Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++'
popuratity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]
colors = ["#1f77b4", "#ff7f0e", "#2ca02c", "#d62728", "#9467bd", "#8c564b"]
# explode 1st slice
explode = (0.1,.1,.1,.1,.1,.1)  

# Plot
plt.pie(popuratity, explode=explode, labels=languages, colors=colors,
autopct='%1.1f%%', shadow=True, startangle=140)

plt.title("POPULARITY OF PROGRAMMING LANGUAGES", bbox = {'facecolor':'0.8', 'pad':5})
plt.axis('equal')
plt.show()
