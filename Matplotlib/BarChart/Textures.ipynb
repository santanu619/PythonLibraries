# %%
'''
@Author: Santanu Mohapatra
@Date: 19/06/2021
@Last Modified by: Santanu Mohapatra
@Last Modified Time: 18:50 PM
@Title: Python program to add textures.
'''

import matplotlib.pyplot as plt
figure = plt.figure()
patterns = ["/","\\","x","@"]

for index in range(len(patterns)):
    plt.bar(index, 3, color='yellow', edgecolor='blue', hatch=patterns[index])

plt.show()
# Out:
# <ipython-input-6-48b8242124bf>:14: MatplotlibDeprecationWarning: hatch must consist of a string of "*+-./OX\ox|" or None, but found the following invalid values "@". Passing invalid values is deprecated since 3.4 and will become an error two minor releases later.
#   plt.bar(index, 3, color='yellow', edgecolor='blue', hatch=patterns[index])
