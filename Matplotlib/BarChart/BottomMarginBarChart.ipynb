# %%
'''
@Author: Santanu Mohapatra
@Date: 19/06/2021
@Last Modified by: Santanu Mohapatra
@Last Modified Time: 16:50 PM
@Title: Python program to display a bar chart of the popularity of the programming language increasing the bottom margins.
'''
import matplotlib.pyplot as plt

programming_languages = ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
popularity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]
programming_languages_pos = [index for index, _ in enumerate(programming_languages)]

plt.bar(programming_languages_pos, popularity, edgecolor='red')
plt.subplots_adjust(bottom=0.4, top=.8)

plt.xlabel("Languages")
plt.ylabel("Popularity")
plt.title("PopularitY of Programming Language")

plt.show()
